# %% [markdown]
# <a href="https://colab.research.google.com/github/18CSE178/DMDW/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib','inline')
plt.style.use('seaborn-whitegrid')

# %%
path="https://raw.githubusercontent.com/18CSE178/DMDW/main/heart_failure_clinical_records_dataset.csv"

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0    75.0        0                       582  ...        0     4            1
# 1    55.0        0                      7861  ...        0     6            1
# 2    65.0        0                       146  ...        1     7            1
# 3    50.0        1                       111  ...        0     7            1
# 4    65.0        1                       160  ...        0     8            1
# ..    ...      ...                       ...  ...      ...   ...          ...
# 294  62.0        0                        61  ...        1   270            0
# 295  55.0        0                      1820  ...        0   271            0
# 296  45.0        0                      2060  ...        0   278            0
# 297  45.0        0                      2413  ...        1   280            0
# 298  50.0        0                       196  ...        1   285            0
#
# [299 rows x 13 columns]

# %%
df1=df[['age','ejection_fraction']]

# %%
df1.head()
# Out:
#     age  ejection_fraction
# 0  75.0                 20
# 1  55.0                 38
# 2  65.0                 20
# 3  50.0                 20
# 4  65.0                 20

# %%
x=df1['age']
y=df1['ejection_fraction']

# %%
sns.lineplot(x,y, dashes=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from scipy.stats import norm

# %%
correlation=df1.corr()
print(correlation)
# Out:
#                         age  ejection_fraction
# age                1.000000           0.060098
# ejection_fraction  0.060098           1.000000

# %%
sns.heatmap(correlation,cmap='BrBG')
plt.show()

# %%
covar=df1.cov()
print(covar)
# Out:
#                           age  ejection_fraction
# age                141.486483           8.460237
# ejection_fraction    8.460237         140.063455

# %%
sns.heatmap(covar)
plt.show()

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0    75.0        0                       582  ...        0     4            1
# 1    55.0        0                      7861  ...        0     6            1
# 2    65.0        0                       146  ...        1     7            1
# 3    50.0        1                       111  ...        0     7            1
# 4    65.0        1                       160  ...        0     8            1
# ..    ...      ...                       ...  ...      ...   ...          ...
# 294  62.0        0                        61  ...        1   270            0
# 295  55.0        0                      1820  ...        0   271            0
# 296  45.0        0                      2060  ...        0   278            0
# 297  45.0        0                      2413  ...        1   280            0
# 298  50.0        0                       196  ...        1   285            0
#
# [299 rows x 13 columns]

# %%
df.shape
# Out:
# (299, 13)

# %%
age=np.array(df['age'])

# %%
age
# Out:
# array([75.   , 55.   , 65.   , 50.   , 65.   , 90.   , 75.   , 60.   ,
#        65.   , 80.   , 75.   , 62.   , 45.   , 50.   , 49.   , 82.   ,
#        87.   , 45.   , 70.   , 48.   , 65.   , 65.   , 68.   , 53.   ,
#        75.   , 80.   , 95.   , 70.   , 58.   , 82.   , 94.   , 85.   ,
#        50.   , 50.   , 65.   , 69.   , 90.   , 82.   , 60.   , 60.   ,
#        70.   , 50.   , 70.   , 72.   , 60.   , 50.   , 51.   , 60.   ,
#        80.   , 57.   , 68.   , 53.   , 60.   , 70.   , 60.   , 95.   ,
#        70.   , 60.   , 49.   , 72.   , 45.   , 50.   , 55.   , 45.   ,
#        45.   , 60.   , 42.   , 72.   , 70.   , 65.   , 41.   , 58.   ,
#        85.   , 65.   , 69.   , 60.   , 70.   , 42.   , 75.   , 55.   ,
#        70.   , 67.   , 60.   , 79.   , 59.   , 51.   , 55.   , 65.   ,
#        44.   , 57.   , 70.   , 60.   , 42.   , 60.   , 58.   , 58.   ,
#        63.   , 70.   , 60.   , 63.   , 65.   , 75.   , 80.   , 42.   ,
# ...

# %%
age=np.array(df['age'])
print("max age",max(age))
age=age.reshape(299,1)
# Out:
# max age 95.0

# %%
age=np.array(df['age'])
print("MIn age",min(age))
age=age.reshape(299,1)
# Out:
# MIn age 40.0

# %%
from scipy import stats
zscore=np.array(stats.zscore(age))
zscore=zscore[0:394]
zscore=zscore.reshape(299,1)

# %%
zscore
# Out:
# array([[ 1.19294523],
#        [-0.49127928],
#        [ 0.35083298],
#        [-0.9123354 ],
#        [ 0.35083298],
#        [ 2.45611361],
#        [ 1.19294523],
#        [-0.07022315],
#        [ 0.35083298],
#        [ 1.61400136],
#        [ 1.19294523],
#        [ 0.0981993 ],
#        [-1.33339153],
#        [-0.9123354 ],
#        [-0.99654663],
#        [ 1.78242381],
#        [ 2.20347993],
#        [-1.33339153],
#        [ 0.7718891 ],
#        [-1.08075785],
#        [ 0.35083298],
#        [ 0.35083298],
#        [ 0.60346665],
#        [-0.65970173],
#        [ 1.19294523],
#        [ 1.61400136],
#        [ 2.87716974],
#        [ 0.7718891 ],
#        [-0.2386456 ],
#        [ 1.78242381],
#        [ 2.79295851],
#        [ 2.03505748],
#        [-0.9123354 ],
#        [-0.9123354 ],
#        [ 0.35083298],
#        [ 0.68767788],
#        [ 2.45611361],
#        [ 1.78242381],
#        [-0.07022315],
#        [-0.07022315],
#        [ 0.7718891 ],
# ...

# %%
dn=[]
dn.append(age/pow(10,2) )
dn=np.array(dn)

# %%
dn
# Out:
# array([[[0.75   ],
#         [0.55   ],
#         [0.65   ],
#         [0.5    ],
#         [0.65   ],
#         [0.9    ],
#         [0.75   ],
#         [0.6    ],
#         [0.65   ],
#         [0.8    ],
#         [0.75   ],
#         [0.62   ],
#         [0.45   ],
#         [0.5    ],
#         [0.49   ],
#         [0.82   ],
#         [0.87   ],
#         [0.45   ],
#         [0.7    ],
#         [0.48   ],
#         [0.65   ],
#         [0.65   ],
#         [0.68   ],
#         [0.53   ],
#         [0.75   ],
#         [0.8    ],
#         [0.95   ],
#         [0.7    ],
#         [0.58   ],
#         [0.82   ],
#         [0.94   ],
#         [0.85   ],
#         [0.5    ],
#         [0.5    ],
#         [0.65   ],
#         [0.69   ],
#         [0.9    ],
#         [0.82   ],
#         [0.6    ],
#         [0.6    ],
#         [0.7    ],
#         [0.5    ],
#         [0.7    ],
#         [0.72   ],
#         [0.6    ],
#         [0.5    ],
#         [0.51   ],
# ...
